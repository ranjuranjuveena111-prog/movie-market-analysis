# %% [markdown]
# # 🎬 Movie Market Analysis
#
# **Company:** CineData Studios
# **Role:** Media Strategy Analyst
#
# ## 🎥 Scenario
#
# CineData Studios is planning their next big production. The executive team wants to analyze historical movie data to determine which genres are currently **most profitable** and **highly rated**, helping guide strategic investment decisions.
#
# ---
#
# ## 🎯 Your Tasks
#
# ### 1️⃣ Rating Score Analysis
#
# * Calculate the **average IMDB rating** across all movies in the dataset.
# * This represents the overall quality benchmark.
#
# ---
#
# ### 2️⃣ Genre King 👑
#
# * Group movies by **Genre**.
# * Compute the **average rating per genre**.
# * Identify which genre has the **highest average rating**.
#
# ---
#
# ### 3️⃣ Financial Impact Analysis
#
# * Create a **Bar Chart** showing:
#
# ```
# Genre vs. Box Office Revenue
# ```
#
# * This will help identify the most financially successful genres.
# * Include:
#
#   * Chart title
#   * Axis labels
#   * Clear formatting
#
# ---
#
# ### 4️⃣ Rating Distribution
#
# * Create a **Histogram** of movie ratings.
#
# * Include:
#
#   * Title
#   * Axis labels
#   * Grid (optional)
#
# * Analyze how ratings are distributed across films.
#
# ---
#
# ### 5️⃣ Success Metric – Hit Identification
#
# * Create a new column called **`Hit`** where:
#
# ```
# Hit = True  if Rating ≥ 8
# Hit = False if Rating < 8
# ```
#
# * This helps classify critically successful movies.
#
# ---
#
# ### 6️⃣ Hit Movie Tally
#
# * Count the total number of **“Hit”** movies in the dataset.
# * Optionally calculate the percentage of hits.
#
# ---
#
# ## 📌 Expected Outcome
#
# By completing this analysis, you should be able to:
#
# * Understand overall movie rating trends
# * Identify the highest-rated genres
# * Analyze revenue performance by genre
# * Recognize critically successful films
# * Provide data-driven recommendations for future productions

# %%
# 2. Max Rating by Genre
df.groupby('Genre')['Rating'].mean().idxmax()

# 3. Revenue Plot
sns.boxplot(x='Genre', y='Revenue', data=df)

# 5. Boolean logic
df['Hit'] = df['Rating'].apply(lambda x: 'Yes' if x >= 8 else 'No')

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/movie_ratings_dataset.csv")

# %%
df
# Out:
#     Movie_ID     Genre  Duration_Minutes  IMDB_Rating  Box_Office_Millions
# 0       4001  Thriller               168          6.8                 77.3
# 1       4002  Thriller               155          6.1                132.1
# 2       4003    Action               125          7.8                276.1
# 3       4004    Comedy               177          9.5                437.8
# 4       4005    Action                98          6.2                222.4
# 5       4006    Action               109          9.1                289.3
# 6       4007     Drama               154          6.6                440.9
# 7       4008    Action                95          7.3                136.5
# 8       4009  Thriller               150          7.6                397.3
# 9       4010  Thriller               104          6.6                486.9
# 10      4011  Thriller               131          8.6                370.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Movie_ID             20 non-null     int64
#  1   Genre                20 non-null     object
#  2   Duration_Minutes     20 non-null     int64
#  3   IMDB_Rating          20 non-null     float64
#  4   Box_Office_Millions  20 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 932.0+ bytes

# %%
df.describe()
# Out:
#          Movie_ID  Duration_Minutes  IMDB_Rating  Box_Office_Millions
# count    20.00000         20.000000    20.000000            20.000000
# mean   4010.50000        137.100000     7.210000           278.850000
# std       5.91608         28.252434     1.224272           134.341272
# min    4001.00000         95.000000     5.200000            35.900000
# 25%    4005.75000        108.000000     6.500000           200.925000
# 50%    4010.50000        145.000000     7.150000           283.350000
# 75%    4015.25000        157.750000     7.850000           377.050000
# max    4020.00000        177.000000     9.500000           486.900000

# %%
df["Duration_Minutes"].mean()
# Out:
# np.float64(137.1)

# %%
df["Duration_Minutes"].min()
# Out:
# 95

# %%
df["Duration_Minutes"].max()
# Out:
# 177

# %%
df.columns
# Out:
# Index(['Movie_ID', 'Genre', 'Duration_Minutes', 'IMDB_Rating',
#        'Box_Office_Millions'],
#       dtype='object')

# %%
df.head()
# Out:
#    Movie_ID     Genre  Duration_Minutes  IMDB_Rating  Box_Office_Millions
# 0      4001  Thriller               168          6.8                 77.3
# 1      4002  Thriller               155          6.1                132.1
# 2      4003    Action               125          7.8                276.1
# 3      4004    Comedy               177          9.5                437.8
# 4      4005    Action                98          6.2                222.4

# %%
df.tail()
# Out:
#     Movie_ID   Genre  Duration_Minutes  IMDB_Rating  Box_Office_Millions
# 15      4016  Comedy               140          5.3                343.2
# 16      4017  Action               153          7.1                459.5
# 17      4018  Comedy               176          6.9                295.1
# 18      4019   Drama               152          7.2                305.8
# 19      4020   Drama                99          5.7                241.7

# %%
len(df)
# Out:
# 20

# %%
df["Genre"]
# Out:
# 0     Thriller
# 1     Thriller
# 2       Action
# 3       Comedy
# 4       Action
# 5       Action
# 6        Drama
# 7       Action
# 8     Thriller
# 9     Thriller
# 10    Thriller
# 11       Drama
# 12    Thriller
# 13    Thriller
# 14       Drama
# 15      Comedy
# 16      Action
# 17      Comedy
# 18       Drama
# 19       Drama
# Name: Genre, dtype: object

# %%
df["IMDB_Rating"].mean()
# Out:
# np.float64(7.209999999999998)

# %%
df["IMDB_Rating"].min()
# Out:
# 5.2

# %%
df[df["IMDB_Rating"]>7]
# Out:
#     Movie_ID     Genre  Duration_Minutes  IMDB_Rating  Box_Office_Millions
# 2       4003    Action               125          7.8                276.1
# 3       4004    Comedy               177          9.5                437.8
# 5       4006    Action               109          9.1                289.3
# 7       4008    Action                95          7.3                136.5
# 8       4009  Thriller               150          7.6                397.3
# 10      4011  Thriller               131          8.6                370.3
# 11      4012     Drama               105          7.6                 74.4
# 12      4013  Thriller               119          8.0                277.4
# 13      4014  Thriller               166          9.0                 35.9
# 16      4017    Action               153          7.1                459.5
# 18      4019     Drama               152          7.2                305.8

# %%
len(df[df["IMDB_Rating"]>7])
# Out:
# 11

# %%
df[df["Genre"]=="Thriller"]
# Out:
#     Movie_ID     Genre  Duration_Minutes  IMDB_Rating  Box_Office_Millions
# 0       4001  Thriller               168          6.8                 77.3
# 1       4002  Thriller               155          6.1                132.1
# 8       4009  Thriller               150          7.6                397.3
# 9       4010  Thriller               104          6.6                486.9
# 10      4011  Thriller               131          8.6                370.3
# 12      4013  Thriller               119          8.0                277.4
# 13      4014  Thriller               166          9.0                 35.9

# %%
df[df["Genre"]=="Action"]
# Out:
#     Movie_ID   Genre  Duration_Minutes  IMDB_Rating  Box_Office_Millions
# 2       4003  Action               125          7.8                276.1
# 4       4005  Action                98          6.2                222.4
# 5       4006  Action               109          9.1                289.3
# 7       4008  Action                95          7.3                136.5
# 16      4017  Action               153          7.1                459.5

# %%
df[df["Genre"]=="Comedy"]
# Out:
#     Movie_ID   Genre  Duration_Minutes  IMDB_Rating  Box_Office_Millions
# 3       4004  Comedy               177          9.5                437.8
# 15      4016  Comedy               140          5.3                343.2
# 17      4018  Comedy               176          6.9                295.1

# %%
df[df["Genre"]=="Drama"]
# Out:
#     Movie_ID  Genre  Duration_Minutes  IMDB_Rating  Box_Office_Millions
# 6       4007  Drama               154          6.6                440.9
# 11      4012  Drama               105          7.6                 74.4
# 14      4015  Drama               166          5.2                277.1
# 18      4019  Drama               152          7.2                305.8
# 19      4020  Drama                99          5.7                241.7

# %%
thriller=df[df["Genre"]=="Thriller"]

# %%
thriller["IMDB_Rating"].mean()
# Out:
# np.float64(7.528571428571429)

# %%
action=df[df["Genre"]=="Action"]

# %%
action["IMDB_Rating"].mean()
# Out:
# np.float64(7.5)

# %%
comedy=df[df["Genre"]=="Comedy"]

# %%
comedy["IMDB_Rating"].mean()
# Out:
# np.float64(7.233333333333334)

# %%
drama=df[df["Genre"]=="Drama"]

# %%
drama["IMDB_Rating"].mean()
# Out:
# np.float64(6.459999999999999)

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df["Genre"],df["Box_Office_Millions"])
plt.title("Genre vs Box Office Revenue")
plt.xlabel("Genre")
plt.ylabel("Box Office Revenue")
# Out:
# Text(0, 0.5, 'Box Office Revenue')

# %%
plt.hist(df["IMDB_Rating"])
plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Genre")
plt.grid(True)

# %%
df["Hit"]=df["IMDB_Rating"]>=8

# %%
df
# Out:
#     Movie_ID     Genre  Duration_Minutes  IMDB_Rating  Box_Office_Millions  \
# 0       4001  Thriller               168          6.8                 77.3
# 1       4002  Thriller               155          6.1                132.1
# 2       4003    Action               125          7.8                276.1
# 3       4004    Comedy               177          9.5                437.8
# 4       4005    Action                98          6.2                222.4
# 5       4006    Action               109          9.1                289.3
# 6       4007     Drama               154          6.6                440.9
# 7       4008    Action                95          7.3                136.5
# 8       4009  Thriller               150          7.6                397.3
# 9       4010  Thriller               104          6.6                486.9
# 10      4011  Thriller               131          8.6                370.3
# ...

# %%
len(df[df["Hit"]==True])
# Out:
# 5
